# %% [markdown]
# **Abiyyu Fathin Derian**
#
# **IYKRA Data Felowship Batch 6**

# %% [markdown]
# ----
# # Data Loading

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew

# %% [markdown]
# ## Load Dataset

# %%
dataset = pd.read_csv('Seasons_Stats.csv')
dataset.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %% [markdown]
# ----
# # Data Preprocessing

# %% [markdown]
# ## Get The Value in 2017

# %%
dataset_2017 = dataset.loc[dataset['Year'] == 2017]
dataset_2017
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 24096       24096  2017.0       Alex Abrines  SG  23.0  OKC  68.0   6.0
# 24097       24097  2017.0         Quincy Acy  PF  26.0  TOT  38.0   1.0
# 24098       24098  2017.0         Quincy Acy  PF  26.0  DAL   6.0   0.0
# 24099       24099  2017.0         Quincy Acy  PF  26.0  BRK  32.0   1.0
# 24100       24100  2017.0       Steven Adams   C  23.0  OKC  80.0  80.0
# ...           ...     ...                ...  ..   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0
#
#            MP   PER  ...    FT%    ORB    DRB    TRB   AST   STL   BLK    TOV  \
# ...

# %% [markdown]
# ## Reset Index The Column

# %%
dataset_2017 = dataset_2017.reset_index(drop=True)
dataset_2017.head()
# Out:
#    Unnamed: 0    Year        Player Pos   Age   Tm     G    GS      MP   PER  \
# 0       24096  2017.0  Alex Abrines  SG  23.0  OKC  68.0   6.0  1055.0  10.1
# 1       24097  2017.0    Quincy Acy  PF  26.0  TOT  38.0   1.0   558.0  11.8
# 2       24098  2017.0    Quincy Acy  PF  26.0  DAL   6.0   0.0    48.0  -1.4
# 3       24099  2017.0    Quincy Acy  PF  26.0  BRK  32.0   1.0   510.0  13.1
# 4       24100  2017.0  Steven Adams   C  23.0  OKC  80.0  80.0  2389.0  16.5
#
#    ...    FT%    ORB    DRB    TRB   AST   STL   BLK    TOV     PF    PTS
# 0  ...  0.898   18.0   68.0   86.0  40.0  37.0   8.0   33.0  114.0  406.0
# 1  ...  0.750   20.0   95.0  115.0  18.0  14.0  15.0   21.0   67.0  222.0
# 2  ...  0.667    2.0    6.0    8.0   0.0   0.0   0.0    2.0    9.0   13.0
# 3  ...  0.754   18.0   89.0  107.0  18.0  14.0  15.0   19.0   58.0  209.0
# 4  ...  0.611  282.0  333.0  615.0  86.0  88.0  78.0  146.0  195.0  905.0
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Check The Column's Names

# %%
dataset_2017.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ## Delete All-Missing Value Column & Unnamed Column

# %%
del dataset_2017['Unnamed: 0']
dataset_2017.head()
# Out:
#      Year        Player Pos   Age   Tm     G    GS      MP   PER    TS%  ...  \
# 0  2017.0  Alex Abrines  SG  23.0  OKC  68.0   6.0  1055.0  10.1  0.560  ...
# 1  2017.0    Quincy Acy  PF  26.0  TOT  38.0   1.0   558.0  11.8  0.565  ...
# 2  2017.0    Quincy Acy  PF  26.0  DAL   6.0   0.0    48.0  -1.4  0.355  ...
# 3  2017.0    Quincy Acy  PF  26.0  BRK  32.0   1.0   510.0  13.1  0.587  ...
# 4  2017.0  Steven Adams   C  23.0  OKC  80.0  80.0  2389.0  16.5  0.589  ...
#
#      FT%    ORB    DRB    TRB   AST   STL   BLK    TOV     PF    PTS
# 0  0.898   18.0   68.0   86.0  40.0  37.0   8.0   33.0  114.0  406.0
# 1  0.750   20.0   95.0  115.0  18.0  14.0  15.0   21.0   67.0  222.0
# 2  0.667    2.0    6.0    8.0   0.0   0.0   0.0    2.0    9.0   13.0
# 3  0.754   18.0   89.0  107.0  18.0  14.0  15.0   19.0   58.0  209.0
# 4  0.611  282.0  333.0  615.0  86.0  88.0  78.0  146.0  195.0  905.0
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Check The Missing Value for All Columns

# %%
dataset_2017.isna().sum()
# Out:
# Year        0
# Player      0
# Pos         0
# Age         0
# Tm          0
# G           0
# GS          0
# MP          0
# PER         0
# TS%         2
# 3PAr        2
# FTr         2
# ORB%        0
# DRB%        0
# TRB%        0
# AST%        0
# STL%        0
# BLK%        0
# TOV%        2
# USG%        0
# blanl     595
# OWS         0
# DWS         0
# WS          0
# WS/48       0
# blank2    595
# OBPM        0
# DBPM        0
# BPM         0
# VORP        0
# FG          0
# FGA         0
# FG%         2
# 3P          0
# 3PA         0
# 3P%        46
# 2P          0
# 2PA         0
# 2P%         5
# eFG%        2
# FT          0
# FTA         0
# FT%        24
# ORB         0
# DRB         0
# TRB         0
# AST         0
# STL         0
# BLK         0
# TOV         0
# PF          0
# PTS         0
# dtype: int64

# %% [markdown]
# ## Delete Columns "blanl" and "blank2"

# %%
dataset_2017 = dataset_2017.drop(['blanl', 'blank2'], axis=1)

# %% [markdown]
# ## Recheck The Column That Contains All Value Null

# %%
dataset_2017.isna().sum()
# Out:
# Year       0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# PER        0
# TS%        2
# 3PAr       2
# FTr        2
# ORB%       0
# DRB%       0
# TRB%       0
# AST%       0
# STL%       0
# BLK%       0
# TOV%       2
# USG%       0
# OWS        0
# DWS        0
# WS         0
# WS/48      0
# OBPM       0
# DBPM       0
# BPM        0
# VORP       0
# FG         0
# FGA        0
# FG%        2
# 3P         0
# 3PA        0
# 3P%       46
# 2P         0
# 2PA        0
# 2P%        5
# eFG%       2
# FT         0
# FTA        0
# FT%       24
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %% [markdown]
# ## Check Duplicated Player's Name

# %%
duplicated_player = dataset_2017[dataset_2017.duplicated('Player')]
duplicated_player.head(15)
# Out:
#       Year            Player Pos   Age   Tm     G    GS      MP   PER    TS%  \
# 2   2017.0        Quincy Acy  PF  26.0  DAL   6.0   0.0    48.0  -1.4  0.355
# 3   2017.0        Quincy Acy  PF  26.0  BRK  32.0   1.0   510.0  13.1  0.587
# 15  2017.0   Justin Anderson  SF  23.0  DAL  51.0   2.0   710.0  14.7  0.521
# 16  2017.0   Justin Anderson  SF  23.0  PHI  24.0   8.0   518.0  12.8  0.564
# 33  2017.0       Matt Barnes  SF  36.0  SAC  54.0  13.0  1367.0  10.2  0.501
# 34  2017.0       Matt Barnes  SF  36.0  GSW  20.0   5.0   410.0  10.7  0.569
# 56  2017.0  Bojan Bogdanovic  SF  27.0  BRK  55.0  54.0  1482.0  13.1  0.572
# 57  2017.0  Bojan Bogdanovic  SF  27.0  WAS  26.0   0.0   601.0  14.7  0.617
# 59  2017.0      Andrew Bogut   C  32.0  DAL  26.0  21.0   582.0   9.4  0.460
# 60  2017.0      Andrew Bogut   C  32.0  CLE   1.0   0.0     1.0 -35.3    NaN
# 66  2017.0      Corey Brewer  SF  30.0  HOU  58.0   8.0   923.0   7.5  0.491
# ...

# %% [markdown]
# ## Drop Duplicated Player's Name

# %%
dataset_2017.drop_duplicates(subset ="Player", keep = 'last', inplace = True)
dataset_2017.head(15)
# Out:
#       Year             Player Pos   Age   Tm     G    GS      MP   PER    TS%  \
# 0   2017.0       Alex Abrines  SG  23.0  OKC  68.0   6.0  1055.0  10.1  0.560
# 3   2017.0         Quincy Acy  PF  26.0  BRK  32.0   1.0   510.0  13.1  0.587
# 4   2017.0       Steven Adams   C  23.0  OKC  80.0  80.0  2389.0  16.5  0.589
# 5   2017.0      Arron Afflalo  SG  31.0  SAC  61.0  45.0  1580.0   9.0  0.559
# 6   2017.0      Alexis Ajinca   C  28.0  NOP  39.0  15.0   584.0  12.9  0.529
# 7   2017.0       Cole Aldrich   C  28.0  MIN  62.0   0.0   531.0  12.7  0.549
# 8   2017.0  LaMarcus Aldridge  PF  31.0  SAS  72.0  72.0  2335.0  18.6  0.532
# 9   2017.0        Lavoy Allen  PF  27.0  IND  61.0   5.0   871.0  11.6  0.485
# 10  2017.0         Tony Allen  SG  35.0  MEM  71.0  66.0  1914.0  13.3  0.493
# 11  2017.0    Al-Farouq Aminu  SF  26.0  POR  61.0  25.0  1773.0  11.3  0.506
# 12  2017.0     Chris Andersen   C  38.0  CLE  12.0   0.0   114.0  11.6  0.497
# ...

# %% [markdown]
# ## Reset Index

# %%
dataset_2017 = dataset_2017.reset_index(drop=True)
dataset_2017
# Out:
#        Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 0    2017.0       Alex Abrines  SG  23.0  OKC  68.0   6.0  1055.0  10.1
# 1    2017.0         Quincy Acy  PF  26.0  BRK  32.0   1.0   510.0  13.1
# 2    2017.0       Steven Adams   C  23.0  OKC  80.0  80.0  2389.0  16.5
# 3    2017.0      Arron Afflalo  SG  31.0  SAC  61.0  45.0  1580.0   9.0
# 4    2017.0      Alexis Ajinca   C  28.0  NOP  39.0  15.0   584.0  12.9
# ..      ...                ...  ..   ...  ...   ...   ...     ...   ...
# 481  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 482  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0  13.0
# 483  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0   7.3
# 484  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0   6.9
# 485  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0  17.0
#
#        TS%  ...    FT%    ORB    DRB    TRB   AST   STL   BLK    TOV     PF  \
# ...

# %% [markdown]
# ## Recheck The Null Value

# %%
dataset_2017.isna().sum()
# Out:
# Year       0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# PER        0
# TS%        2
# 3PAr       2
# FTr        2
# ORB%       0
# DRB%       0
# TRB%       0
# AST%       0
# STL%       0
# BLK%       0
# TOV%       2
# USG%       0
# OWS        0
# DWS        0
# WS         0
# WS/48      0
# OBPM       0
# DBPM       0
# BPM        0
# VORP       0
# FG         0
# FGA        0
# FG%        2
# 3P         0
# 3PA        0
# 3P%       39
# 2P         0
# 2PA        0
# 2P%        4
# eFG%       2
# FT         0
# FTA        0
# FT%       18
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %% [markdown]
# ## Change The Null Value for Columns 'TS%', '3PAr', 'FTr', 'TOV%', 'FG%', '2P%', 'eFG%'

# %%
dataset_2017.update(dataset_2017[['TS%', '3PAr', 'FTr', 'TOV%', 'FG%', '2P%', 'eFG%']].fillna(0.0))

# %% [markdown]
# ## Recheck The Null Value

# %%
dataset_2017.isna().sum()
# Out:
# Year       0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# PER        0
# TS%        0
# 3PAr       0
# FTr        0
# ORB%       0
# DRB%       0
# TRB%       0
# AST%       0
# STL%       0
# BLK%       0
# TOV%       0
# USG%       0
# OWS        0
# DWS        0
# WS         0
# WS/48      0
# OBPM       0
# DBPM       0
# BPM        0
# VORP       0
# FG         0
# FGA        0
# FG%        0
# 3P         0
# 3PA        0
# 3P%       39
# 2P         0
# 2PA        0
# 2P%        0
# eFG%       0
# FT         0
# FTA        0
# FT%       18
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %% [markdown]
# ## Check The Skewness of The Column '3P%'

# %%
skew(dataset_2017['3P%'].dropna())
# Out:
# -0.4563312064435094

# %% [markdown]
# ## Fill The NaN of Column '3P%' with Its Median

# %%
dataset_2017['3P%'].fillna(dataset_2017['3P%'].median(), inplace=True)
dataset_2017['3P%'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Recheck The Null Value

# %%
dataset_2017.isna().sum()
# Out:
# Year       0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# PER        0
# TS%        0
# 3PAr       0
# FTr        0
# ORB%       0
# DRB%       0
# TRB%       0
# AST%       0
# STL%       0
# BLK%       0
# TOV%       0
# USG%       0
# OWS        0
# DWS        0
# WS         0
# WS/48      0
# OBPM       0
# DBPM       0
# BPM        0
# VORP       0
# FG         0
# FGA        0
# FG%        0
# 3P         0
# 3PA        0
# 3P%        0
# 2P         0
# 2PA        0
# 2P%        0
# eFG%       0
# FT         0
# FTA        0
# FT%       18
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %% [markdown]
# ## Check The Skewness of The Column 'FT%'

# %%
skew(dataset_2017['FT%'].dropna())
# Out:
# -1.6536899360680632

# %% [markdown]
# ## Fill The NaN of Column 'FT%' with Its Median

# %%
dataset_2017['FT%'].fillna(dataset_2017['FT%'].median(), inplace=True)
dataset_2017['FT%'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Recheck The Null Value

# %%
dataset_2017.isna().sum()
# Out:
# Year      0
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# PER       0
# TS%       0
# 3PAr      0
# FTr       0
# ORB%      0
# DRB%      0
# TRB%      0
# AST%      0
# STL%      0
# BLK%      0
# TOV%      0
# USG%      0
# OWS       0
# DWS       0
# WS        0
# WS/48     0
# OBPM      0
# DBPM      0
# BPM       0
# VORP      0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# dtype: int64

# %% [markdown]
# -----
# # Answer The Problem Questions

# %% [markdown]
# ## 1. Who is the youngest and oldest player in the NBA in 2017 for each team (Tm)?

# %%
answer_1 = dataset_2017[['Player', 'Age', 'Tm']]
answer_1
# Out:
#                 Player   Age   Tm
# 0         Alex Abrines  23.0  OKC
# 1           Quincy Acy  26.0  BRK
# 2         Steven Adams  23.0  OKC
# 3        Arron Afflalo  31.0  SAC
# 4        Alexis Ajinca  28.0  NOP
# ..                 ...   ...  ...
# 481        Cody Zeller  24.0  CHO
# 482       Tyler Zeller  27.0  BOS
# 483  Stephen Zimmerman  20.0  ORL
# 484        Paul Zipser  22.0  CHI
# 485        Ivica Zubac  19.0  LAL
#
# [486 rows x 3 columns]

# %% [markdown]
# ### Find The Youngest Player in Each Team

# %%
answer_1[['Tm', 'Player', 'Age']].groupby('Tm').min().reset_index()
# Out:
#      Tm            Player   Age
# 0   ATL   DeAndre' Bembry  22.0
# 1   BOS        Al Horford  20.0
# 2   BRK  Andrew Nicholson  21.0
# 3   CHI    Anthony Morrow  21.0
# 4   CHO    Aaron Harrison  21.0
# 5   CLE      Andrew Bogut  21.0
# 6   DAL      A.J. Hammons  21.0
# 7   DEN        Alonzo Gee  19.0
# 8   DET    Andre Drummond  20.0
# 9   GSW  Anderson Varejao  20.0
# 10  HOU       Bobby Brown  20.0
# 11  IND      Aaron Brooks  20.0
# 12  LAC     Alan Anderson  19.0
# 13  LAL    Brandon Ingram  19.0
# 14  MEM   Andrew Harrison  20.0
# 15  MIA      Dion Waiters  20.0
# 16  MIL       Gary Payton  19.0
# 17  MIN     Adreian Payne  20.0
# 18  NOP     Alexis Ajinca  20.0
# 19  NYK   Carmelo Anthony  21.0
# 20  OKC      Alex Abrines  20.0
# 21  ORL      Aaron Gordon  20.0
# 22  PHI    Alex Poythress  21.0
# 23  PHO     Alan Williams  19.0
# 24  POR   Al-Farouq Aminu  21.0
# 25  SAC  Anthony Tolliver  19.0
# 26  SAS       Bryn Forbes  20.0
# 27  TOR     Bruno Caboclo  21.0
# ...

# %% [markdown]
# ### Find The Oldest Player in Each Team

# %%
answer_1[['Tm', 'Player', 'Age']].groupby('Tm').max().reset_index()
# Out:
#      Tm                   Player   Age
# 0   ATL             Tim Hardaway  36.0
# 1   BOS             Tyler Zeller  31.0
# 2   BRK            Trevor Booker  36.0
# 3   CHI              Robin Lopez  35.0
# 4   CHO           Treveon Graham  31.0
# 5   CLE         Tristan Thompson  38.0
# 6   DAL             Yogi Ferrell  38.0
# 7   DEN          Wilson Chandler  36.0
# 8   DET            Tobias Harris  34.0
# 9   GSW            Zaza Pachulia  36.0
# 10  HOU            Troy Williams  34.0
# 11  IND           Thaddeus Young  32.0
# 12  LAC           Wesley Johnson  39.0
# 13  LAL              Tyler Ennis  37.0
# 14  MEM            Zach Randolph  40.0
# 15  MIA              Willie Reed  36.0
# 16  MIL               Tony Snell  39.0
# 17  MIN              Zach LaVine  34.0
# 18  NOP              Tim Frazier  33.0
# 19  NYK        Willy Hernangomez  32.0
# 20  OKC           Victor Oladipo  36.0
# 21  ORL            Terrence Ross  32.0
# 22  PHI  Timothe Luwawu-Cabarrot  32.0
# ...

# %% [markdown]
# ## 2. Which player has the most minutes played (MP) in each position (Pos)?

# %%
answer_2 = dataset_2017[['Player', 'MP', 'Pos']]
answer_2
# Out:
#                 Player      MP Pos
# 0         Alex Abrines  1055.0  SG
# 1           Quincy Acy   510.0  PF
# 2         Steven Adams  2389.0   C
# 3        Arron Afflalo  1580.0  SG
# 4        Alexis Ajinca   584.0   C
# ..                 ...     ...  ..
# 481        Cody Zeller  1725.0  PF
# 482       Tyler Zeller   525.0   C
# 483  Stephen Zimmerman   108.0   C
# 484        Paul Zipser   843.0  SF
# 485        Ivica Zubac   609.0   C
#
# [486 rows x 3 columns]

# %%
answer_2[['Pos', 'Player', 'MP']].groupby('Pos').max().reset_index()
# Out:
#   Pos           Player      MP
# 0   C    Zaza Pachulia  3030.0
# 1  PF    Zach Randolph  2803.0
# 2  PG     Yogi Ferrell  2947.0
# 3  SF  Wilson Chandler  3048.0
# 4  SG      Zach LaVine  2796.0

# %% [markdown]
# ## 3. Which team has the highest average total rebound percentage (TRB%), assist percentage (AST%), steal percentage (STL%), and block percentage (BLK%)?

# %%
answer_3 = dataset_2017[['Tm', 'TRB%', 'AST%', 'STL%', 'BLK%']]
answer_3
# Out:
#       Tm  TRB%  AST%  STL%  BLK%
# 0    OKC   4.5   5.5   1.7   0.6
# 1    BRK  11.1   5.4   1.3   2.2
# 2    OKC  14.2   5.4   1.8   2.6
# 3    SAC   4.6   7.4   0.7   0.4
# 4    NOP  16.0   3.1   1.7   3.1
# ..   ...   ...   ...   ...   ...
# 481  CHO  12.9   9.1   1.8   3.0
# 482  BOS  13.2  12.2   0.7   3.3
# 483  ORL  17.6   5.3   0.9   3.7
# 484  CHI   8.0   6.1   0.9   1.5
# 485  LAL  14.3   8.1   1.1   4.4
#
# [486 rows x 5 columns]

# %%
avg_answer_3 = answer_3.groupby(['Tm'], as_index=False)['TRB%', 'AST%', 'STL%', 'BLK%'].mean()
avg_answer_3
# Out:
# <ipython-input-264-9cb763547b66>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_answer_3 = answer_3.groupby(['Tm'], as_index=False)['TRB%', 'AST%', 'STL%', 'BLK%'].mean()
#      Tm       TRB%       AST%      STL%      BLK%
# 0   ATL   9.627778  14.083333  1.438889  1.522222
# 1   BOS  10.360000  14.573333  1.366667  1.493333
# 2   BRK   9.894444  13.616667  1.483333  1.444444
# 3   CHI   9.343750  13.037500  1.543750  1.068750
# 4   CHO   9.617647  13.888235  1.300000  1.247059
# 5   CLE   9.668421  11.073684  1.194737  2.568421
# 6   DAL  10.852632  13.563158  1.536842  1.663158
# 7   DEN  10.829412  15.723529  1.747059  1.882353
# 8   DET  10.326667  13.200000  1.260000  1.173333
# 9   GSW  11.475000  13.943750  1.712500  2.675000
# 10  HOU   9.520000  12.493333  1.573333  1.506667
# 11  IND  10.156250  13.425000  1.437500  1.525000
# 12  LAC  10.586667  12.033333  1.993333  2.053333
# ...

# %% [markdown]
# ### Find The Highest Average TRB%

# %%
avg_answer_3[avg_answer_3['TRB%'] == avg_answer_3['TRB%'].max()][['Tm','TRB%']].reset_index()
# Out:
#    index   Tm       TRB%
# 0     29  WAS  12.735294

# %% [markdown]
# ### Find The Highest Average AST%

# %%
avg_answer_3[avg_answer_3['AST%'] == avg_answer_3['AST%'].max()][['Tm','AST%']].reset_index()
# Out:
#    index   Tm       AST%
# 0      7  DEN  15.723529

# %% [markdown]
# ### Find The Highest Average STL%

# %%
avg_answer_3[avg_answer_3['STL%'] == avg_answer_3['STL%'].max()][['Tm','STL%']].reset_index()
# Out:
#    index   Tm      STL%
# 0     17  MIN  2.413333

# %% [markdown]
# ### Find The Highest Average BLK%

# %%
avg_answer_3[avg_answer_3['BLK%'] == avg_answer_3['BLK%'].max()][['Tm','BLK%']].reset_index()
# Out:
#    index   Tm      BLK%
# 0     16  MIL  2.741176

# %% [markdown]
# ## 4. Who is the best player in your opinion based on his record stats?

# %% [markdown]
# To decide the best player, I choose the overall rating score based on these selected data, they are **AST, BLK, DRB, ORB, TRB, STL, TOV, PF, and PTS**. It is because these data is the inherent skill of the player.

# %%
answer_4 = dataset_2017[['Player', 'AST', 'BLK', 'DRB', 'ORB', 'TRB', 'STL', 'TOV', 'PF', 'PTS']]
answer_4
# Out:
#                 Player   AST   BLK    DRB    ORB    TRB   STL    TOV     PF  \
# 0         Alex Abrines  40.0   8.0   68.0   18.0   86.0  37.0   33.0  114.0
# 1           Quincy Acy  18.0  15.0   89.0   18.0  107.0  14.0   19.0   58.0
# 2         Steven Adams  86.0  78.0  333.0  282.0  615.0  88.0  146.0  195.0
# 3        Arron Afflalo  78.0   7.0  116.0    9.0  125.0  21.0   42.0  104.0
# 4        Alexis Ajinca  12.0  22.0  131.0   46.0  177.0  20.0   31.0   77.0
# ..                 ...   ...   ...    ...    ...    ...   ...    ...    ...
# 481        Cody Zeller  99.0  58.0  270.0  135.0  405.0  62.0   65.0  189.0
# 482       Tyler Zeller  42.0  21.0   81.0   43.0  124.0   7.0   20.0   61.0
# 483  Stephen Zimmerman   4.0   5.0   24.0   11.0   35.0   2.0    3.0   17.0
# 484        Paul Zipser  36.0  16.0  110.0   15.0  125.0  15.0   40.0   78.0
# 485        Ivica Zubac  30.0  33.0  118.0   41.0  159.0  14.0   30.0   66.0
#
#        PTS
# 0    406.0
# 1    209.0
# 2    905.0
# ...

# %% [markdown]
# ### Calculate The Average Overall Score

# %%
answer_4['Avg_Overall'] = answer_4.mean(axis=1)
answer_4
# Out:
# <ipython-input-285-02da5be4623b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   answer_4['Avg_Overall'] = answer_4.mean(axis=1)
#                 Player   AST   BLK    DRB    ORB    TRB   STL    TOV     PF  \
# 0         Alex Abrines  40.0   8.0   68.0   18.0   86.0  37.0   33.0  114.0
# 1           Quincy Acy  18.0  15.0   89.0   18.0  107.0  14.0   19.0   58.0
# 2         Steven Adams  86.0  78.0  333.0  282.0  615.0  88.0  146.0  195.0
# 3        Arron Afflalo  78.0   7.0  116.0    9.0  125.0  21.0   42.0  104.0
# 4        Alexis Ajinca  12.0  22.0  131.0   46.0  177.0  20.0   31.0   77.0
# ..                 ...   ...   ...    ...    ...    ...   ...    ...    ...
# ...

# %% [markdown]
# ### Define The Best Player

# %%
The_Best_Player = answer_4[answer_4['Avg_Overall'] == answer_4['Avg_Overall'].max()]
The_Best_Player
# Out:
#                 Player    AST   BLK    DRB    ORB    TRB    STL    TOV     PF  \
# 457  Russell Westbrook  840.0  31.0  727.0  137.0  864.0  133.0  438.0  190.0
#
#         PTS  Avg_Overall
# 457  2558.0   657.555556

# %% [markdown]
# ## 5.	Which team has the best average stat record of their players?

# %%
answer_5 = dataset_2017[['Player', 'Tm', 'AST', 'BLK', 'DRB', 'ORB', 'TRB', 'STL', 'TOV', 'PF', 'PTS']]
answer_5
# Out:
#                 Player   Tm   AST   BLK    DRB    ORB    TRB   STL    TOV  \
# 0         Alex Abrines  OKC  40.0   8.0   68.0   18.0   86.0  37.0   33.0
# 1           Quincy Acy  BRK  18.0  15.0   89.0   18.0  107.0  14.0   19.0
# 2         Steven Adams  OKC  86.0  78.0  333.0  282.0  615.0  88.0  146.0
# 3        Arron Afflalo  SAC  78.0   7.0  116.0    9.0  125.0  21.0   42.0
# 4        Alexis Ajinca  NOP  12.0  22.0  131.0   46.0  177.0  20.0   31.0
# ..                 ...  ...   ...   ...    ...    ...    ...   ...    ...
# 481        Cody Zeller  CHO  99.0  58.0  270.0  135.0  405.0  62.0   65.0
# 482       Tyler Zeller  BOS  42.0  21.0   81.0   43.0  124.0   7.0   20.0
# 483  Stephen Zimmerman  ORL   4.0   5.0   24.0   11.0   35.0   2.0    3.0
# 484        Paul Zipser  CHI  36.0  16.0  110.0   15.0  125.0  15.0   40.0
# 485        Ivica Zubac  LAL  30.0  33.0  118.0   41.0  159.0  14.0   30.0
#
#         PF    PTS
# 0    114.0  406.0
# 1     58.0  209.0
# 2    195.0  905.0
# ...

# %%
answer_5['Avg_Overall'] = answer_4.mean(axis=1)
answer_5
# Out:
# <ipython-input-289-56e938f5807b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   answer_5['Avg_Overall'] = answer_4.mean(axis=1)
#                 Player   Tm   AST   BLK    DRB    ORB    TRB   STL    TOV  \
# 0         Alex Abrines  OKC  40.0   8.0   68.0   18.0   86.0  37.0   33.0
# 1           Quincy Acy  BRK  18.0  15.0   89.0   18.0  107.0  14.0   19.0
# 2         Steven Adams  OKC  86.0  78.0  333.0  282.0  615.0  88.0  146.0
# 3        Arron Afflalo  SAC  78.0   7.0  116.0    9.0  125.0  21.0   42.0
# 4        Alexis Ajinca  NOP  12.0  22.0  131.0   46.0  177.0  20.0   31.0
# ..                 ...  ...   ...   ...    ...    ...    ...   ...    ...
# 481        Cody Zeller  CHO  99.0  58.0  270.0  135.0  405.0  62.0   65.0
# ...

# %%
Avg_Overall_of_Team = answer_5[['Tm', 'Player', 'Avg_Overall']].groupby('Tm').mean().reset_index()
Avg_Overall_of_Team
# Out:
#      Tm  Avg_Overall
# 0   ATL   128.351852
# 1   BOS   159.192593
# 2   BRK   123.141975
# 3   CHI   130.763889
# 4   CHO   126.738562
# 5   CLE   120.865497
# 6   DAL    97.175439
# 7   DEN   138.993464
# 8   DET   154.185185
# 9   GSW   162.166667
# 10  HOU   159.622222
# 11  IND   146.618056
# 12  LAC   158.748148
# 13  LAL   133.729167
# 14  MEM   142.465278
# 15  MIA   164.753968
# 16  MIL   135.071895
# 17  MIN   157.555556
# 18  NOP   109.718954
# 19  NYK   149.622222
# 20  OKC   152.037037
# 21  ORL   116.061728
# 22  PHI   128.555556
# 23  PHO   135.196078
# 24  POR   154.849206
# 25  SAC   107.395833
# 26  SAS   149.194444
# 27  TOR   139.270833
# 28  UTA   152.333333
# 29  WAS   141.196078

# %% [markdown]
# ### Rename The Name of Column

# %%
Avg_Overall_of_Team = Avg_Overall_of_Team.rename(columns={"Avg_Overall": "Avg_Overall_Team"})
Avg_Overall_of_Team
# Out:
#      Tm  Avg_Overall_Team
# 0   ATL        128.351852
# 1   BOS        159.192593
# 2   BRK        123.141975
# 3   CHI        130.763889
# 4   CHO        126.738562
# 5   CLE        120.865497
# 6   DAL         97.175439
# 7   DEN        138.993464
# 8   DET        154.185185
# 9   GSW        162.166667
# 10  HOU        159.622222
# 11  IND        146.618056
# 12  LAC        158.748148
# 13  LAL        133.729167
# 14  MEM        142.465278
# 15  MIA        164.753968
# 16  MIL        135.071895
# 17  MIN        157.555556
# 18  NOP        109.718954
# 19  NYK        149.622222
# 20  OKC        152.037037
# 21  ORL        116.061728
# 22  PHI        128.555556
# 23  PHO        135.196078
# 24  POR        154.849206
# 25  SAC        107.395833
# 26  SAS        149.194444
# 27  TOR        139.270833
# 28  UTA        152.333333
# 29  WAS        141.196078

# %% [markdown]
# ### Define The Result of The team has the best average stat record of their players

# %%
Avg_Overall_of_Team[Avg_Overall_of_Team['Avg_Overall_Team'] == Avg_Overall_of_Team['Avg_Overall_Team'].max()][['Tm','Avg_Overall_Team']].reset_index()
# Out:
#    index   Tm  Avg_Overall_Team
# 0     15  MIA        164.753968
